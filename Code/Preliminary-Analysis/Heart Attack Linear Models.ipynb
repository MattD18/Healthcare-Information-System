# %%
using DataFrames, StatsBase

# %% [markdown]
# Useful Functions

# %%
#function that calculates out-of-sample error
#w = parameter array fit to model
#model = function that fits a model on a dataset
#test_set = dataset being tested
function out_sample_error(w,model,test_set)
    test_size = size(test_set,1)
    model_X = model(test_set)[2]
    model_output = round(model_X*w)
    model_error = 0
    for i in 1:test_size
        if test_set[:Survived][i] != model_output[i]
            model_error = model_error + 1
        end
    end
    return model_error / test_size
end

#function that runs a bootstrap estimation on the training set
#model = function that fits a model on a dataset
#resample_num = number of samples
function bootstrap_estimate(model,training_data
    ;resample_num = 1000)
    w_bs = 0
    td_size = size(training_data,1)
    for i in 1:resample_num
        #randomly samples from training set
        train_sample = training_data[sample(1:td_size,round(Int,.5*td_size)), :] 
        #incrememts bootstrap parameter by parameter of new sample
        w_bs = w_bs + model(train_sample)[1]
    end
    #finds average parameter among trials
    w_bs = w_bs / resample_num
    return w_bs
end 

#function that partitions data into train and test sets,
#runs model on train and checks error on test
#model = function that fits a model on a dataset
#training_data = dataset to be partitioned and crossvalidated
#k = number of partitions 
function cross_validate(model, training_data;
    k = 5)
    error_cv = 0
    td_size = size(training_data,1)
    #size of 1 partition when they are k partitions 
    partition = round(Int,td_size / k)
    for i in 1:k
        #creates training and test sets for this iteration
        s = (i-1)*partition + 1 
        if i == k 
            f = td_size
        else
            f = i*partition
        end
        #test partition with size 1/kth of dataset
        round_test = training_data[s:f,:]
        round_train_1 = training_data[1:s-1,:]
        round_train_2 = training_data[f+1:td_size,:]
        #training partition
        round_train = [round_train_1;round_train_2]
        #w when model is run on training set
        round_w = model(round_train)[1]
        #error in w when model run on test set
        round_error = out_sample_error(round_w,model,round_test)
        error_cv = error_cv + round_error
    end
    #average error among partitions 
    error_cv = error_cv / k
    return error_cv
end

#helper function for split_data
function build_subset(index,data)
    subset = similar(data,0)
    for i in 1:length(index)
        new_row = DataArray(data[data[:x] .== index[i],:])
        push!(subset,new_row)
    end
    return subset
end 

#splits dataset into train and test sets
#splits data based on the discharge identifier column :x (integer)
#split_raio = ratio of training set size to entire dataset size
function split_data(data_set;split_ratio = .8)
    n = size(data_set,1)
    split = Int(round(split_ratio*n))
    rand_index = shuffle(data_set[:x])
    train_index = rand_index[1:split]
    test_index = rand_index[split + 1:n]
    train = build_subset(train_index,data_set)
    test = build_subset(test_index,data_set)
    return(train,test)
end
# Out:
# split_data (generic function with 1 method)

# %% [markdown]
# Analysis

# %%
#import data
heart_attack = readtable("heart_attack.csv")
# Out:
# 1072×50 DataFrames.DataFrame
# │ Row  │ x       │ Health_Service_Area │ Hospital_County │
# ├──────┼─────────┼─────────────────────┼─────────────────┤
# │ 1    │ 3577    │ "Western NY"        │ "Cattaraugus"   │
# │ 2    │ 5411    │ "Western NY"        │ "Cattaraugus"   │
# │ 3    │ 8169    │ "Western NY"        │ "Chautauqua"    │
# │ 4    │ 9390    │ "Western NY"        │ "Chautauqua"    │
# │ 5    │ 16311   │ "Western NY"        │ "Chautauqua"    │
# │ 6    │ 17014   │ "Western NY"        │ "Chautauqua"    │
# │ 7    │ 17754   │ "Western NY"        │ "Chautauqua"    │
# │ 8    │ 19217   │ "Western NY"        │ "Chautauqua"    │
# │ 9    │ 21080   │ "Western NY"        │ "Erie"          │
# │ 10   │ 21508   │ "Western NY"        │ "Erie"          │
# │ 11   │ 21640   │ "Western NY"        │ "Erie"          │
# ⋮
# │ 1061 │ 2519026 │ "Long Island"       │ "Suffolk"       │
# │ 1062 │ 2527331 │ "Long Island"       │ "Suffolk"       │
# │ 1063 │ 2532210 │ "Long Island"       │ "Suffolk"       │
# │ 1064 │ 2535046 │ "Long Island"       │ "Suffolk"       │
# │ 1065 │ 2535333 │ "Long Island"       │ "Suffolk"       │
# │ 1066 │ 2537506 │ "Long Island"       │ "Suffolk"       │
# │ 1067 │ 2538641 │ "Long Island"       │ "Suffolk"       │
# │ 1068 │ 2539035 │ "Long Island"       │ "Suffolk"       │
# │ 1069 │ 2540093 │ "Long Island"       │ "Suffolk"       │
# │ 1070 │ 2542897 │ "Long Island"       │ "Suffolk"       │
# │ 1071 │ 2543672 │ "Long Island"       │ "Suffolk"       │
# │ 1072 │ 2544724 │ "Long Island"       │ "Suffolk"       │
#
# │ Row  │ Operating_Certificate_Number │ Facility_Id │
# ├──────┼──────────────────────────────┼─────────────┤
# │ 1    │ 401001                       │ 66          │
# │ 2    │ 401001                       │ 66          │
# │ 3    │ 601000                       │ 98          │
# │ 4    │ 601000                       │ 98          │
# │ 5    │ 602001                       │ 103         │
# │ 6    │ 602001                       │ 103         │
# │ 7    │ 602001                       │ 103         │
# │ 8    │ 427000                       │ 114         │
# │ 9    │ 1401014                      │ 207         │
# │ 10   │ 1401014                      │ 207         │
# │ 11   │ 1401014                      │ 207         │
# ⋮
# │ 1061 │ 5154001                      │ 925         │
# │ 1062 │ 5155000                      │ 938         │
# │ 1063 │ 5157003                      │ 943         │
# │ 1064 │ 5157003                      │ 943         │
# │ 1065 │ 5157003                      │ 943         │
# │ 1066 │ 5157003                      │ 943         │
# │ 1067 │ 5157003                      │ 943         │
# │ 1068 │ 5157003                      │ 943         │
# │ 1069 │ 5157003                      │ 943         │
# │ 1070 │ 5157003                      │ 943         │
# │ 1071 │ 5157003                      │ 943         │
# │ 1072 │ 5157003                      │ 943         │
#
# │ Row  │ Facility_Name                            │ Age_Group     │
# ├──────┼──────────────────────────────────────────┼───────────────┤
# │ 1    │ "Olean General Hospital"                 │ "70 or Older" │
# │ 2    │ "Olean General Hospital"                 │ "18 to 29"    │
# │ 3    │ "Brooks Memorial Hospital"               │ "70 or Older" │
# │ 4    │ "Brooks Memorial Hospital"               │ "70 or Older" │
# │ 5    │ "Woman's Christian Association"          │ "50 to 69"    │
# │ 6    │ "Woman's Christian Association"          │ "70 or Older" │
# │ 7    │ "Woman's Christian Association"          │ "70 or Older" │
# │ 8    │ "TLC Health Network Lake Shore Hospital" │ "70 or Older" │
# │ 9    │ "Buffalo General Hospital"               │ "50 to 69"    │
# │ 10   │ "Buffalo General Hospital"               │ "70 or Older" │
# │ 11   │ "Buffalo General Hospital"               │ "70 or Older" │
# ⋮
# │ 1061 │ "Good Samaritan Hospital Medical Center" │ "50 to 69"    │
# │ 1062 │ "Peconic Bay Medical Center"             │ "70 or Older" │
# │ 1063 │ "St Catherine of Siena Hospital"         │ "50 to 69"    │
# │ 1064 │ "St Catherine of Siena Hospital"         │ "50 to 69"    │
# │ 1065 │ "St Catherine of Siena Hospital"         │ "18 to 29"    │
# │ 1066 │ "St Catherine of Siena Hospital"         │ "70 or Older" │
# │ 1067 │ "St Catherine of Siena Hospital"         │ "70 or Older" │
# │ 1068 │ "St Catherine of Siena Hospital"         │ "70 or Older" │
# │ 1069 │ "St Catherine of Siena Hospital"         │ "30 to 49"    │
# │ 1070 │ "St Catherine of Siena Hospital"         │ "50 to 69"    │
# │ 1071 │ "St Catherine of Siena Hospital"         │ "50 to 69"    │
# │ 1072 │ "St Catherine of Siena Hospital"         │ "70 or Older" │
#
# │ Row  │ Zip_Code_3_digits │ Gender │ Race         │ Ethnicity           │
# ├──────┼───────────────────┼────────┼──────────────┼─────────────────────┤
# │ 1    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 2    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 3    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 4    │ "141"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 5    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 6    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 7    │ "147"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 8    │ "141"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 9    │ "141"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 10   │ "140"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 11   │ "141"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# ⋮
# │ 1061 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1062 │ "119"             │ "M"    │ "Other Race" │ "Spanish/Hispanic"  │
# │ 1063 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1064 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1065 │ "117"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 1066 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1067 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1068 │ "117"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 1069 │ "117"             │ "M"    │ "White"      │ "Not Span/Hispanic" │
# │ 1070 │ "117"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 1071 │ "117"             │ "F"    │ "White"      │ "Not Span/Hispanic" │
# │ 1072 │ "117"             │ "F"    │ "White"      │ "Spanish/Hispanic"  │
#
# │ Row  │ Length_of_Stay │ Admit_Day_of_Week │ Type_of_Admission │
# ├──────┼────────────────┼───────────────────┼───────────────────┤
# │ 1    │ "9"            │ "TUE"             │ "Emergency"       │
# │ 2    │ "2"            │ "TUE"             │ "Emergency"       │
# │ 3    │ "1"            │ "SAT"             │ "Emergency"       │
# │ 4    │ "2"            │ "MON"             │ "Urgent"          │
# │ 5    │ "5"            │ "FRI"             │ "Urgent"          │
# │ 6    │ "2"            │ "WED"             │ "Urgent"          │
# │ 7    │ "4"            │ "FRI"             │ "Urgent"          │
# │ 8    │ "1"            │ "TUE"             │ "Emergency"       │
# │ 9    │ "3"            │ "TUE"             │ "Urgent"          │
# │ 10   │ "3"            │ "MON"             │ "Urgent"          │
# │ 11   │ "47"           │ "TUE"             │ "Urgent"          │
# ⋮
# │ 1061 │ "6"            │ "THU"             │ "Emergency"       │
# │ 1062 │ "21"           │ "SUN"             │ "Emergency"       │
# │ 1063 │ "5"            │ "THU"             │ "Emergency"       │
# │ 1064 │ "1"            │ "MON"             │ "Emergency"       │
# │ 1065 │ "1"            │ "MON"             │ "Emergency"       │
# │ 1066 │ "1"            │ "MON"             │ "Emergency"       │
# │ 1067 │ "2"            │ "TUE"             │ "Emergency"       │
# │ 1068 │ "1"            │ "SAT"             │ "Emergency"       │
# │ 1069 │ "2"            │ "SUN"             │ "Emergency"       │
# │ 1070 │ "20"           │ "WED"             │ "Emergency"       │
# │ 1071 │ "21"           │ "WED"             │ "Emergency"       │
# │ 1072 │ "1"            │ "SAT"             │ "Emergency"       │
#
# │ Row  │ Patient_Disposition            │ Discharge_Year │
# ├──────┼────────────────────────────────┼────────────────┤
# │ 1    │ "Short-term Hospital"          │ 2012           │
# │ 2    │ "Expired"                      │ 2012           │
# │ 3    │ "Expired"                      │ 2012           │
# │ 4    │ "Expired"                      │ 2012           │
# │ 5    │ "Home or Self Care"            │ 2012           │
# │ 6    │ "Home or Self Care"            │ 2012           │
# │ 7    │ "Skilled Nursing Home"         │ 2012           │
# │ 8    │ "Expired"                      │ 2012           │
# │ 9    │ "Home or Self Care"            │ 2012           │
# │ 10   │ "Home or Self Care"            │ 2012           │
# │ 11   │ "Expired"                      │ 2012           │
# ⋮
# │ 1061 │ "Home or Self Care"            │ 2012           │
# │ 1062 │ "Short-term Hospital"          │ 2012           │
# │ 1063 │ "Home w/ Home Health Services" │ 2012           │
# │ 1064 │ "Home or Self Care"            │ 2012           │
# │ 1065 │ "Expired"                      │ 2012           │
# │ 1066 │ "Expired"                      │ 2012           │
# │ 1067 │ "Expired"                      │ 2012           │
# │ 1068 │ "Expired"                      │ 2012           │
# │ 1069 │ "Expired"                      │ 2012           │
# │ 1070 │ "Expired"                      │ 2012           │
# │ 1071 │ "Skilled Nursing Home"         │ 2012           │
# │ 1072 │ "Expired"                      │ 2012           │
#
# │ Row  │ Discharge_Day_of_Week │ CCS_Diagnosis_Code │
# ├──────┼───────────────────────┼────────────────────┤
# │ 1    │ "THU"                 │ 107                │
# │ 2    │ "THU"                 │ 107                │
# │ 3    │ "SUN"                 │ 107                │
# │ 4    │ "WED"                 │ 107                │
# │ 5    │ "WED"                 │ 107                │
# │ 6    │ "FRI"                 │ 107                │
# │ 7    │ "TUE"                 │ 107                │
# │ 8    │ "TUE"                 │ 107                │
# │ 9    │ "FRI"                 │ 107                │
# │ 10   │ "THU"                 │ 107                │
# │ 11   │ "SUN"                 │ 107                │
# ⋮
# │ 1061 │ "WED"                 │ 107                │
# │ 1062 │ "SUN"                 │ 107                │
# │ 1063 │ "TUE"                 │ 107                │
# │ 1064 │ "TUE"                 │ 107                │
# │ 1065 │ "TUE"                 │ 107                │
# │ 1066 │ "MON"                 │ 107                │
# │ 1067 │ "THU"                 │ 107                │
# │ 1068 │ "SUN"                 │ 107                │
# │ 1069 │ "TUE"                 │ 107                │
# │ 1070 │ "TUE"                 │ 107                │
# │ 1071 │ "WED"                 │ 107                │
# │ 1072 │ "SUN"                 │ 107                │
#
# │ Row  │ CCS_Diagnosis_Description │ CCS_Procedure_Code │
# ├──────┼───────────────────────────┼────────────────────┤
# │ 1    │ "CARDIAC ARREST & VF"     │ 227                │
# │ 2    │ "CARDIAC ARREST & VF"     │ 227                │
# │ 3    │ "CARDIAC ARREST & VF"     │ 229                │
# │ 4    │ "CARDIAC ARREST & VF"     │ 216                │
# │ 5    │ "CARDIAC ARREST & VF"     │ 225                │
# │ 6    │ "CARDIAC ARREST & VF"     │ 227                │
# │ 7    │ "CARDIAC ARREST & VF"     │ 177                │
# │ 8    │ "CARDIAC ARREST & VF"     │ 216                │
# │ 9    │ "CARDIAC ARREST & VF"     │ 48                 │
# │ 10   │ "CARDIAC ARREST & VF"     │ 62                 │
# │ 11   │ "CARDIAC ARREST & VF"     │ 70                 │
# ⋮
# │ 1061 │ "CARDIAC ARREST & VF"     │ 48                 │
# │ 1062 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1063 │ "CARDIAC ARREST & VF"     │ 0                  │
# │ 1064 │ "CARDIAC ARREST & VF"     │ 0                  │
# │ 1065 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1066 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1067 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1068 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1069 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1070 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1071 │ "CARDIAC ARREST & VF"     │ 216                │
# │ 1072 │ "CARDIAC ARREST & VF"     │ 54                 │
#
# │ Row  │ CCS_Procedure_Description │ APR_DRG_Code │
# ├──────┼───────────────────────────┼──────────────┤
# │ 1    │ "OT DX PRC (INTERVW,EVAL" │ 196          │
# │ 2    │ "OT DX PRC (INTERVW,EVAL" │ 196          │
# │ 3    │ "NONOP RMVL FOREIGN BODY" │ 196          │
# │ 4    │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 5    │ "CONV OF CARDIAC RHYTHM"  │ 196          │
# │ 6    │ "OT DX PRC (INTERVW,EVAL" │ 196          │
# │ 7    │ "COMP AXIAL TOMOGR (CT)"  │ 196          │
# │ 8    │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 9    │ "CARDIAC PACEMAKER/DEFIB" │ 161          │
# │ 10   │ "OT DX CARDIOVASC PRCS"   │ 196          │
# │ 11   │ "UP GASTRO ENDOSC/BIOPSY" │ 196          │
# ⋮
# │ 1061 │ "CARDIAC PACEMAKER/DEFIB" │ 161          │
# │ 1062 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1063 │ "NO PROC"                 │ 196          │
# │ 1064 │ "NO PROC"                 │ 196          │
# │ 1065 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1066 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1067 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1068 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1069 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1070 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1071 │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 1072 │ "OT VASC CATH; NOT HEART" │ 196          │
#
# │ Row  │ APR_DRG_Description                            │ APR_MDC_Code │
# ├──────┼────────────────────────────────────────────────┼──────────────┤
# │ 1    │ "CARDIAC ARREST"                               │ 5            │
# │ 2    │ "CARDIAC ARREST"                               │ 5            │
# │ 3    │ "CARDIAC ARREST"                               │ 5            │
# │ 4    │ "CARDIAC ARREST"                               │ 5            │
# │ 5    │ "CARDIAC ARREST"                               │ 5            │
# │ 6    │ "CARDIAC ARREST"                               │ 5            │
# │ 7    │ "CARDIAC ARREST"                               │ 5            │
# │ 8    │ "CARDIAC ARREST"                               │ 5            │
# │ 9    │ "CARDIAC DEFIBRILLATOR & HEART ASSIST IMPLANT" │ 5            │
# │ 10   │ "CARDIAC ARREST"                               │ 5            │
# │ 11   │ "CARDIAC ARREST"                               │ 5            │
# ⋮
# │ 1061 │ "CARDIAC DEFIBRILLATOR & HEART ASSIST IMPLANT" │ 5            │
# │ 1062 │ "CARDIAC ARREST"                               │ 5            │
# │ 1063 │ "CARDIAC ARREST"                               │ 5            │
# │ 1064 │ "CARDIAC ARREST"                               │ 5            │
# │ 1065 │ "CARDIAC ARREST"                               │ 5            │
# │ 1066 │ "CARDIAC ARREST"                               │ 5            │
# │ 1067 │ "CARDIAC ARREST"                               │ 5            │
# │ 1068 │ "CARDIAC ARREST"                               │ 5            │
# │ 1069 │ "CARDIAC ARREST"                               │ 5            │
# │ 1070 │ "CARDIAC ARREST"                               │ 5            │
# │ 1071 │ "CARDIAC ARREST"                               │ 5            │
# │ 1072 │ "CARDIAC ARREST"                               │ 5            │
#
# │ Row  │ APR_MDC_Description                                │
# ├──────┼────────────────────────────────────────────────────┤
# │ 1    │ "Diseases and Disorders of the Circulatory System" │
# │ 2    │ "Diseases and Disorders of the Circulatory System" │
# │ 3    │ "Diseases and Disorders of the Circulatory System" │
# │ 4    │ "Diseases and Disorders of the Circulatory System" │
# │ 5    │ "Diseases and Disorders of the Circulatory System" │
# │ 6    │ "Diseases and Disorders of the Circulatory System" │
# │ 7    │ "Diseases and Disorders of the Circulatory System" │
# │ 8    │ "Diseases and Disorders of the Circulatory System" │
# │ 9    │ "Diseases and Disorders of the Circulatory System" │
# │ 10   │ "Diseases and Disorders of the Circulatory System" │
# │ 11   │ "Diseases and Disorders of the Circulatory System" │
# ⋮
# │ 1061 │ "Diseases and Disorders of the Circulatory System" │
# │ 1062 │ "Diseases and Disorders of the Circulatory System" │
# │ 1063 │ "Diseases and Disorders of the Circulatory System" │
# │ 1064 │ "Diseases and Disorders of the Circulatory System" │
# │ 1065 │ "Diseases and Disorders of the Circulatory System" │
# │ 1066 │ "Diseases and Disorders of the Circulatory System" │
# │ 1067 │ "Diseases and Disorders of the Circulatory System" │
# │ 1068 │ "Diseases and Disorders of the Circulatory System" │
# │ 1069 │ "Diseases and Disorders of the Circulatory System" │
# │ 1070 │ "Diseases and Disorders of the Circulatory System" │
# │ 1071 │ "Diseases and Disorders of the Circulatory System" │
# │ 1072 │ "Diseases and Disorders of the Circulatory System" │
#
# │ Row  │ APR_Severity_of_Illness_Code │ APR_Severity_of_Illness_Description │
# ├──────┼──────────────────────────────┼─────────────────────────────────────┤
# │ 1    │ 2                            │ "Moderate"                          │
# │ 2    │ 3                            │ "Major"                             │
# │ 3    │ 3                            │ "Major"                             │
# │ 4    │ 3                            │ "Major"                             │
# │ 5    │ 4                            │ "Extreme"                           │
# │ 6    │ 2                            │ "Moderate"                          │
# │ 7    │ 2                            │ "Moderate"                          │
# │ 8    │ 3                            │ "Major"                             │
# │ 9    │ 1                            │ "Minor"                             │
# │ 10   │ 2                            │ "Moderate"                          │
# │ 11   │ 4                            │ "Extreme"                           │
# ⋮
# │ 1061 │ 2                            │ "Moderate"                          │
# │ 1062 │ 4                            │ "Extreme"                           │
# │ 1063 │ 2                            │ "Moderate"                          │
# │ 1064 │ 2                            │ "Moderate"                          │
# │ 1065 │ 4                            │ "Extreme"                           │
# │ 1066 │ 3                            │ "Major"                             │
# │ 1067 │ 3                            │ "Major"                             │
# │ 1068 │ 3                            │ "Major"                             │
# │ 1069 │ 4                            │ "Extreme"                           │
# │ 1070 │ 4                            │ "Extreme"                           │
# │ 1071 │ 4                            │ "Extreme"                           │
# │ 1072 │ 3                            │ "Major"                             │
#
# │ Row  │ APR_Risk_of_Mortality │ APR_Medical_Surgical_Description │
# ├──────┼───────────────────────┼──────────────────────────────────┤
# │ 1    │ "Moderate"            │ "Medical"                        │
# │ 2    │ "Moderate"            │ "Medical"                        │
# │ 3    │ "Extreme"             │ "Medical"                        │
# │ 4    │ "Major"               │ "Medical"                        │
# │ 5    │ "Major"               │ "Medical"                        │
# │ 6    │ "Moderate"            │ "Medical"                        │
# │ 7    │ "Moderate"            │ "Medical"                        │
# │ 8    │ "Major"               │ "Medical"                        │
# │ 9    │ "Minor"               │ "Surgical"                       │
# │ 10   │ "Moderate"            │ "Medical"                        │
# │ 11   │ "Extreme"             │ "Medical"                        │
# ⋮
# │ 1061 │ "Moderate"            │ "Surgical"                       │
# │ 1062 │ "Extreme"             │ "Medical"                        │
# │ 1063 │ "Moderate"            │ "Medical"                        │
# │ 1064 │ "Minor"               │ "Medical"                        │
# │ 1065 │ "Extreme"             │ "Medical"                        │
# │ 1066 │ "Major"               │ "Medical"                        │
# │ 1067 │ "Major"               │ "Medical"                        │
# │ 1068 │ "Major"               │ "Medical"                        │
# │ 1069 │ "Extreme"             │ "Medical"                        │
# │ 1070 │ "Extreme"             │ "Medical"                        │
# │ 1071 │ "Extreme"             │ "Medical"                        │
# │ 1072 │ "Major"               │ "Medical"                        │
#
# │ Row  │ Payment_Typology_1         │ Payment_Typology_2         │
# ├──────┼────────────────────────────┼────────────────────────────┤
# │ 1    │ "Medicare"                 │ "Medicaid"                 │
# │ 2    │ "Self-Pay"                 │ ""                         │
# │ 3    │ "Medicare"                 │ ""                         │
# │ 4    │ "Blue Cross/Blue Shield"   │ ""                         │
# │ 5    │ "Medicare"                 │ "Medicare"                 │
# │ 6    │ "Medicare"                 │ "Medicare"                 │
# │ 7    │ "Medicare"                 │ "Medicare"                 │
# │ 8    │ "Medicare"                 │ ""                         │
# │ 9    │ "Blue Cross/Blue Shield"   │ "Self-Pay"                 │
# │ 10   │ "Medicare"                 │ "Private Health Insurance" │
# │ 11   │ "Medicare"                 │ "Self-Pay"                 │
# ⋮
# │ 1061 │ "Medicaid"                 │ "Medicaid"                 │
# │ 1062 │ "Medicare"                 │ "Private Health Insurance" │
# │ 1063 │ "Blue Cross/Blue Shield"   │ ""                         │
# │ 1064 │ "Blue Cross/Blue Shield"   │ ""                         │
# │ 1065 │ "Private Health Insurance" │ ""                         │
# │ 1066 │ "Medicare"                 │ "Blue Cross/Blue Shield"   │
# │ 1067 │ "Medicare"                 │ "Private Health Insurance" │
# │ 1068 │ "Medicare"                 │ "Blue Cross/Blue Shield"   │
# │ 1069 │ "Medicaid"                 │ ""                         │
# │ 1070 │ "Medicare"                 │ "Medicaid"                 │
# │ 1071 │ "Blue Cross/Blue Shield"   │ ""                         │
# │ 1072 │ "Medicare"                 │ "Medicaid"                 │
#
# │ Row  │ Payment_Typology_3 │ Attending_Provider_License_Number │
# ├──────┼────────────────────┼───────────────────────────────────┤
# │ 1    │ ""                 │ 264217                            │
# │ 2    │ ""                 │ 141658                            │
# │ 3    │ ""                 │ 239319                            │
# │ 4    │ ""                 │ 261189                            │
# │ 5    │ ""                 │ 138697                            │
# │ 6    │ ""                 │ 142873                            │
# │ 7    │ ""                 │ 3876                              │
# │ 8    │ ""                 │ 200012                            │
# │ 9    │ ""                 │ 144605                            │
# │ 10   │ "Self-Pay"         │ 229275                            │
# │ 11   │ ""                 │ 40003114                          │
# ⋮
# │ 1061 │ ""                 │ 229976                            │
# │ 1062 │ ""                 │ 194902                            │
# │ 1063 │ ""                 │ 241578                            │
# │ 1064 │ ""                 │ 94617                             │
# │ 1065 │ ""                 │ 250405                            │
# │ 1066 │ ""                 │ 241578                            │
# │ 1067 │ ""                 │ 116667                            │
# │ 1068 │ ""                 │ 244844                            │
# │ 1069 │ ""                 │ 265526                            │
# │ 1070 │ ""                 │ 265510                            │
# │ 1071 │ ""                 │ 244672                            │
# │ 1072 │ ""                 │ 265526                            │
#
# │ Row  │ Operating_Provider_License_Number │ Other_Provider_License_Number │
# ├──────┼───────────────────────────────────┼───────────────────────────────┤
# │ 1    │ 149079                            │ NA                            │
# │ 2    │ 3053                              │ NA                            │
# │ 3    │ 217335                            │ 217335                        │
# │ 4    │ 240432                            │ NA                            │
# │ 5    │ 129581                            │ NA                            │
# │ 6    │ 172738                            │ NA                            │
# │ 7    │ 130444                            │ NA                            │
# │ 8    │ 118047                            │ NA                            │
# │ 9    │ 144605                            │ NA                            │
# │ 10   │ 229275                            │ NA                            │
# │ 11   │ 204462                            │ 259232                        │
# ⋮
# │ 1061 │ 194503                            │ NA                            │
# │ 1062 │ 194902                            │ NA                            │
# │ 1063 │ NA                                │ NA                            │
# │ 1064 │ NA                                │ NA                            │
# │ 1065 │ 215767                            │ NA                            │
# │ 1066 │ 232929                            │ NA                            │
# │ 1067 │ 167445                            │ NA                            │
# │ 1068 │ 244844                            │ NA                            │
# │ 1069 │ 167033                            │ NA                            │
# │ 1070 │ 265510                            │ NA                            │
# │ 1071 │ 266941                            │ NA                            │
# │ 1072 │ 265526                            │ NA                            │
#
# │ Row  │ Birth_Weight │ Abortion_Edit_Indicator │
# ├──────┼──────────────┼─────────────────────────┤
# │ 1    │ 0            │ "N"                     │
# │ 2    │ 0            │ "N"                     │
# │ 3    │ 0            │ "N"                     │
# │ 4    │ 0            │ "N"                     │
# │ 5    │ 0            │ "N"                     │
# │ 6    │ 0            │ "N"                     │
# │ 7    │ 0            │ "N"                     │
# │ 8    │ 0            │ "N"                     │
# │ 9    │ 0            │ "N"                     │
# │ 10   │ 0            │ "N"                     │
# │ 11   │ 0            │ "N"                     │
# ⋮
# │ 1061 │ 0            │ "N"                     │
# │ 1062 │ 0            │ "N"                     │
# │ 1063 │ 0            │ "N"                     │
# │ 1064 │ 0            │ "N"                     │
# │ 1065 │ 0            │ "N"                     │
# │ 1066 │ 0            │ "N"                     │
# │ 1067 │ 0            │ "N"                     │
# │ 1068 │ 0            │ "N"                     │
# │ 1069 │ 0            │ "N"                     │
# │ 1070 │ 0            │ "N"                     │
# │ 1071 │ 0            │ "N"                     │
# │ 1072 │ 0            │ "N"                     │
#
# │ Row  │ Emergency_Department_Indicator │ Total_Charges │ Total_Costs │
# ├──────┼────────────────────────────────┼───────────────┼─────────────┤
# │ 1    │ "Y"                            │ "\$18461.03"   │ "\$5148.18"  │
# │ 2    │ "Y"                            │ "\$16729.38"   │ "\$7543.35"  │
# │ 3    │ "Y"                            │ "\$7145.49"    │ "\$6382.73"  │
# │ 4    │ "N"                            │ "\$6343.38"    │ "\$10022.09" │
# │ 5    │ "Y"                            │ "\$18324.66"   │ "\$9180.61"  │
# │ 6    │ "Y"                            │ "\$6871.94"    │ "\$2752.50"  │
# │ 7    │ "Y"                            │ "\$7905.27"    │ "\$3959.88"  │
# │ 8    │ "Y"                            │ "\$3810.29"    │ "\$1638.08"  │
# │ 9    │ "N"                            │ "\$61974.35"   │ "\$28926.80" │
# │ 10   │ "N"                            │ "\$7754.39"    │ "\$3803.11"  │
# │ 11   │ "N"                            │ "\$156935.11"  │ "\$80308.85" │
# ⋮
# │ 1061 │ "Y"                            │ "\$250731.60"  │ "\$92603.30" │
# │ 1062 │ "Y"                            │ "\$252410.70"  │ "\$69537.50" │
# │ 1063 │ "Y"                            │ "\$26805.00"   │ "\$6516.43"  │
# │ 1064 │ "Y"                            │ "\$9747.50"    │ "\$1828.79"  │
# │ 1065 │ "Y"                            │ "\$27354.00"   │ "\$5576.71"  │
# │ 1066 │ "Y"                            │ "\$9270.00"    │ "\$1856.23"  │
# │ 1067 │ "Y"                            │ "\$27262.00"   │ "\$6623.81"  │
# │ 1068 │ "Y"                            │ "\$21876.00"   │ "\$5243.12"  │
# │ 1069 │ "Y"                            │ "\$32258.00"   │ "\$7276.51"  │
# │ 1070 │ "Y"                            │ "\$141320.00"  │ "\$37046.85" │
# │ 1071 │ "Y"                            │ "\$207987.00"  │ "\$54903.26" │
# │ 1072 │ "Y"                            │ "\$15423.00"   │ "\$2766.89"  │
#
# │ Row  │ Survived │ Male │ White │ Black │ Other_Race │ private_insurance │
# ├──────┼──────────┼──────┼───────┼───────┼────────────┼───────────────────┤
# │ 1    │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 2    │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 3    │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 4    │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 5    │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 6    │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 7    │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 8    │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 9    │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 10   │ 1        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 11   │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# ⋮
# │ 1061 │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1062 │ 1        │ 1    │ 0     │ 0     │ 1          │ 0                 │
# │ 1063 │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1064 │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1065 │ 0        │ 0    │ 1     │ 0     │ 0          │ 1                 │
# │ 1066 │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1067 │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1068 │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 1069 │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 1070 │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 1071 │ 1        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 1072 │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
#
# │ Row  │ medicare │ medicaid │ old50_69 │ old70 │
# ├──────┼──────────┼──────────┼──────────┼───────┤
# │ 1    │ 1        │ 0        │ 0        │ 1     │
# │ 2    │ 0        │ 0        │ 0        │ 0     │
# │ 3    │ 1        │ 0        │ 0        │ 1     │
# │ 4    │ 0        │ 0        │ 0        │ 1     │
# │ 5    │ 1        │ 0        │ 1        │ 0     │
# │ 6    │ 1        │ 0        │ 0        │ 1     │
# │ 7    │ 1        │ 0        │ 0        │ 1     │
# │ 8    │ 1        │ 0        │ 0        │ 1     │
# │ 9    │ 0        │ 0        │ 1        │ 0     │
# │ 10   │ 1        │ 0        │ 0        │ 1     │
# │ 11   │ 1        │ 0        │ 0        │ 1     │
# ⋮
# │ 1061 │ 0        │ 1        │ 1        │ 0     │
# │ 1062 │ 1        │ 0        │ 0        │ 1     │
# │ 1063 │ 0        │ 0        │ 1        │ 0     │
# │ 1064 │ 0        │ 0        │ 1        │ 0     │
# │ 1065 │ 0        │ 0        │ 0        │ 0     │
# │ 1066 │ 1        │ 0        │ 0        │ 1     │
# │ 1067 │ 1        │ 0        │ 0        │ 1     │
# │ 1068 │ 1        │ 0        │ 0        │ 1     │
# │ 1069 │ 0        │ 1        │ 0        │ 0     │
# │ 1070 │ 1        │ 0        │ 1        │ 0     │
# │ 1071 │ 0        │ 0        │ 1        │ 0     │
# │ 1072 │ 1        │ 0        │ 0        │ 1     │

# %% [markdown]
# Data Cleaning

# %%
#hospital stays with length > 120 days labeled as "120 +"
#change these to length 120
heart_attack[heart_attack[:Length_of_Stay] .== "120 +",12] = "120"

#convert length of stay value to float
heart_attack[:Length_of_Stay] = float(heart_attack[:Length_of_Stay])
# Out:
# 1072-element Array{Float64,1}:
#   9.0
#   2.0
#   1.0
#   2.0
#   5.0
#   2.0
#   4.0
#   1.0
#   3.0
#   3.0
#  47.0
#   6.0
#   4.0
#   ⋮
#   6.0
#  21.0
#   5.0
#   1.0
#   1.0
#   1.0
#   2.0
#   1.0
#   2.0
#  20.0
#  21.0
#   1.0

# %% [markdown]
# Split Into Train and Test

# %%
#only looking at NYC hospital data
NYC_data = heart_attack[heart_attack[:Health_Service_Area] .== "New York City",:]
train = split_data(NYC_data)[1]
test = split_data(NYC_data)[2]
# Out:
# 90×50 DataFrames.DataFrame
# │ Row │ x       │ Health_Service_Area │ Hospital_County │
# ├─────┼─────────┼─────────────────────┼─────────────────┤
# │ 1   │ 1293012 │ "New York City"     │ "Kings"         │
# │ 2   │ 1060616 │ "New York City"     │ "Bronx"         │
# │ 3   │ 1539466 │ "New York City"     │ "Manhattan"     │
# │ 4   │ 1946335 │ "New York City"     │ "Queens"        │
# │ 5   │ 1787452 │ "New York City"     │ "Manhattan"     │
# │ 6   │ 1022731 │ "New York City"     │ "Bronx"         │
# │ 7   │ 1495304 │ "New York City"     │ "Manhattan"     │
# │ 8   │ 2136626 │ "New York City"     │ "Richmond"      │
# │ 9   │ 1179320 │ "New York City"     │ "Kings"         │
# │ 10  │ 1708462 │ "New York City"     │ "Manhattan"     │
# │ 11  │ 1534435 │ "New York City"     │ "Manhattan"     │
# ⋮
# │ 79  │ 1751330 │ "New York City"     │ "Manhattan"     │
# │ 80  │ 1186933 │ "New York City"     │ "Kings"         │
# │ 81  │ 1215023 │ "New York City"     │ "Kings"         │
# │ 82  │ 1894864 │ "New York City"     │ "Manhattan"     │
# │ 83  │ 1922754 │ "New York City"     │ "Queens"        │
# │ 84  │ 2094368 │ "New York City"     │ "Queens"        │
# │ 85  │ 1403716 │ "New York City"     │ "Kings"         │
# │ 86  │ 1236942 │ "New York City"     │ "Kings"         │
# │ 87  │ 2122902 │ "New York City"     │ "Richmond"      │
# │ 88  │ 1257918 │ "New York City"     │ "Kings"         │
# │ 89  │ 1285793 │ "New York City"     │ "Kings"         │
# │ 90  │ 2061646 │ "New York City"     │ "Queens"        │
#
# │ Row │ Operating_Certificate_Number │ Facility_Id │
# ├─────┼──────────────────────────────┼─────────────┤
# │ 1   │ 7001019                      │ 1304        │
# │ 2   │ 7000008                      │ 1172        │
# │ 3   │ 7002002                      │ 1439        │
# │ 4   │ 7003003                      │ 1629        │
# │ 5   │ 7002054                      │ 1464        │
# │ 6   │ 7000006                      │ 1169        │
# │ 7   │ 7002001                      │ 1438        │
# │ 8   │ 7004003                      │ 1740        │
# │ 9   │ 7001002                      │ 1286        │
# │ 10  │ 7002024                      │ 1456        │
# │ 11  │ 7002002                      │ 1439        │
# ⋮
# │ 79  │ 7002054                      │ 1458        │
# │ 80  │ 7001002                      │ 1286        │
# │ 81  │ 7001009                      │ 1294        │
# │ 82  │ 7002054                      │ 3975        │
# │ 83  │ 7003000                      │ 1626        │
# │ 84  │ 7002024                      │ 1639        │
# │ 85  │ 7001035                      │ 1318        │
# │ 86  │ 7001016                      │ 1301        │
# │ 87  │ 7004010                      │ 1738        │
# │ 88  │ 7001037                      │ 1302        │
# │ 89  │ 7001019                      │ 1304        │
# │ 90  │ 7003010                      │ 1637        │
#
# │ Row │ Facility_Name                                                    │
# ├─────┼──────────────────────────────────────────────────────────────────┤
# │ 1   │ "NYU Lutheran Medical Center"                                    │
# │ 2   │ "Lincoln Medical & Mental Health Center"                         │
# │ 3   │ "Mount Sinai Beth Israel"                                        │
# │ 4   │ "Jamaica Hospital Medical Center"                                │
# │ 5   │ "New York Presbyterian Hospital - Columbia Presbyterian Center"  │
# │ 6   │ "Montefiore Medical Center - Henry & Lucy Moses Div"             │
# │ 7   │ "Bellevue Hospital Center"                                       │
# │ 8   │ "Staten Island University Hosp-North"                            │
# │ 9   │ "Brookdale Hospital Medical Center"                              │
# │ 10  │ "Mount Sinai Hospital"                                           │
# │ 11  │ "Mount Sinai Beth Israel"                                        │
# ⋮
# │ 79  │ "New York Presbyterian Hospital - New York Weill Cornell Center" │
# │ 80  │ "Brookdale Hospital Medical Center"                              │
# │ 81  │ "Coney Island Hospital"                                          │
# │ 82  │ "New York Presbyterian Hospital - Allen Hospital"                │
# │ 83  │ "Elmhurst Hospital Center"                                       │
# │ 84  │ "Mount Sinai Hospital - Mount Sinai Hospital of Queens"          │
# │ 85  │ "Wyckoff Heights Medical Center"                                 │
# │ 86  │ "Kings County Hospital Center"                                   │
# │ 87  │ "Richmond University Medical Center"                             │
# │ 88  │ "SUNY Downstate Medical Center at LICH"                          │
# │ 89  │ "NYU Lutheran Medical Center"                                    │
# │ 90  │ "New York Hospital Medical Center of Queens"                     │
#
# │ Row │ Age_Group     │ Zip_Code_3_digits │ Gender │ Race                     │
# ├─────┼───────────────┼───────────────────┼────────┼──────────────────────────┤
# │ 1   │ "50 to 69"    │ "112"             │ "F"    │ "White"                  │
# │ 2   │ "50 to 69"    │ "104"             │ "M"    │ "Other Race"             │
# │ 3   │ "50 to 69"    │ "100"             │ "M"    │ "White"                  │
# │ 4   │ "50 to 69"    │ "114"             │ "F"    │ "Other Race"             │
# │ 5   │ "70 or Older" │ "OOS"             │ "M"    │ "White"                  │
# │ 6   │ "70 or Older" │ "104"             │ "M"    │ "Black/African American" │
# │ 7   │ "30 to 49"    │ "118"             │ "F"    │ "Other Race"             │
# │ 8   │ "70 or Older" │ "103"             │ "M"    │ "White"                  │
# │ 9   │ "50 to 69"    │ "112"             │ "M"    │ "Black/African American" │
# │ 10  │ "50 to 69"    │ "100"             │ "M"    │ "Black/African American" │
# │ 11  │ "70 or Older" │ "100"             │ "M"    │ "Other Race"             │
# ⋮
# │ 79  │ "70 or Older" │ "100"             │ "M"    │ "Other Race"             │
# │ 80  │ "70 or Older" │ "112"             │ "F"    │ "Black/African American" │
# │ 81  │ "70 or Older" │ "112"             │ "M"    │ "White"                  │
# │ 82  │ "70 or Older" │ "104"             │ "F"    │ "White"                  │
# │ 83  │ "70 or Older" │ "113"             │ "M"    │ "Other Race"             │
# │ 84  │ "50 to 69"    │ "111"             │ "F"    │ "Other Race"             │
# │ 85  │ "70 or Older" │ "113"             │ "F"    │ "White"                  │
# │ 86  │ "70 or Older" │ "112"             │ "F"    │ "Black/African American" │
# │ 87  │ "50 to 69"    │ "103"             │ "M"    │ "White"                  │
# │ 88  │ "70 or Older" │ "112"             │ "F"    │ "Black/African American" │
# │ 89  │ "70 or Older" │ "112"             │ "F"    │ "White"                  │
# │ 90  │ "70 or Older" │ "113"             │ "M"    │ "White"                  │
#
# │ Row │ Ethnicity           │ Length_of_Stay │ Admit_Day_of_Week │
# ├─────┼─────────────────────┼────────────────┼───────────────────┤
# │ 1   │ "Not Span/Hispanic" │ 4.0            │ "FRI"             │
# │ 2   │ "Spanish/Hispanic"  │ 2.0            │ "SUN"             │
# │ 3   │ "Not Span/Hispanic" │ 1.0            │ "THU"             │
# │ 4   │ "Spanish/Hispanic"  │ 18.0           │ "SAT"             │
# │ 5   │ "Not Span/Hispanic" │ 3.0            │ "TUE"             │
# │ 6   │ "Not Span/Hispanic" │ 7.0            │ "SUN"             │
# │ 7   │ "Not Span/Hispanic" │ 25.0           │ "MON"             │
# │ 8   │ "Not Span/Hispanic" │ 11.0           │ "SAT"             │
# │ 9   │ "Not Span/Hispanic" │ 1.0            │ "THU"             │
# │ 10  │ "Not Span/Hispanic" │ 4.0            │ "FRI"             │
# │ 11  │ "Not Span/Hispanic" │ 1.0            │ "SUN"             │
# ⋮
# │ 79  │ "Not Span/Hispanic" │ 13.0           │ "FRI"             │
# │ 80  │ "Not Span/Hispanic" │ 1.0            │ "FRI"             │
# │ 81  │ "Not Span/Hispanic" │ 1.0            │ "WED"             │
# │ 82  │ "Not Span/Hispanic" │ 1.0            │ "THU"             │
# │ 83  │ "Not Span/Hispanic" │ 8.0            │ "FRI"             │
# │ 84  │ "Not Span/Hispanic" │ 1.0            │ "SAT"             │
# │ 85  │ "Unknown"           │ 6.0            │ "WED"             │
# │ 86  │ "Not Span/Hispanic" │ 22.0           │ "WED"             │
# │ 87  │ "Not Span/Hispanic" │ 6.0            │ "WED"             │
# │ 88  │ "Not Span/Hispanic" │ 1.0            │ "TUE"             │
# │ 89  │ "Not Span/Hispanic" │ 1.0            │ "THU"             │
# │ 90  │ "Not Span/Hispanic" │ 4.0            │ "THU"             │
#
# │ Row │ Type_of_Admission │ Patient_Disposition            │ Discharge_Year │
# ├─────┼───────────────────┼────────────────────────────────┼────────────────┤
# │ 1   │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 2   │ "Emergency"       │ "Home or Self Care"            │ 2012           │
# │ 3   │ "Emergency"       │ "Home or Self Care"            │ 2012           │
# │ 4   │ "Emergency"       │ "Home or Self Care"            │ 2012           │
# │ 5   │ "Elective"        │ "Home or Self Care"            │ 2012           │
# │ 6   │ "Emergency"       │ "Home w/ Home Health Services" │ 2012           │
# │ 7   │ "Emergency"       │ "Hospice - Medical Facility"   │ 2012           │
# │ 8   │ "Emergency"       │ "Home or Self Care"            │ 2012           │
# │ 9   │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 10  │ "Emergency"       │ "Home w/ Home Health Services" │ 2012           │
# │ 11  │ "Emergency"       │ "Expired"                      │ 2012           │
# ⋮
# │ 79  │ "Emergency"       │ "Hospice - Medical Facility"   │ 2012           │
# │ 80  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 81  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 82  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 83  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 84  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 85  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 86  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 87  │ "Emergency"       │ "Home or Self Care"            │ 2012           │
# │ 88  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 89  │ "Emergency"       │ "Expired"                      │ 2012           │
# │ 90  │ "Emergency"       │ "Expired"                      │ 2012           │
#
# │ Row │ Discharge_Day_of_Week │ CCS_Diagnosis_Code │ CCS_Diagnosis_Description │
# ├─────┼───────────────────────┼────────────────────┼───────────────────────────┤
# │ 1   │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 2   │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 3   │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 4   │ "WED"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 5   │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 6   │ "SUN"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 7   │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 8   │ "WED"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 9   │ "THU"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 10  │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 11  │ "MON"                 │ 107                │ "CARDIAC ARREST & VF"     │
# ⋮
# │ 79  │ "THU"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 80  │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 81  │ "WED"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 82  │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 83  │ "SAT"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 84  │ "SAT"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 85  │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 86  │ "THU"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 87  │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 88  │ "TUE"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 89  │ "FRI"                 │ 107                │ "CARDIAC ARREST & VF"     │
# │ 90  │ "MON"                 │ 107                │ "CARDIAC ARREST & VF"     │
#
# │ Row │ CCS_Procedure_Code │ CCS_Procedure_Description │ APR_DRG_Code │
# ├─────┼────────────────────┼───────────────────────────┼──────────────┤
# │ 1   │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 2   │ 227                │ "OT DX PRC (INTERVW,EVAL" │ 196          │
# │ 3   │ 227                │ "OT DX PRC (INTERVW,EVAL" │ 196          │
# │ 4   │ 48                 │ "CARDIAC PACEMAKER/DEFIB" │ 161          │
# │ 5   │ 48                 │ "CARDIAC PACEMAKER/DEFIB" │ 177          │
# │ 6   │ 48                 │ "CARDIAC PACEMAKER/DEFIB" │ 161          │
# │ 7   │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 8   │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 9   │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 10  │ 193                │ "DX ULTRASOUND HEART"     │ 196          │
# │ 11  │ 226                │ "OT DX RADIO & RELATED"   │ 196          │
# ⋮
# │ 79  │ 47                 │ "DX CARDIAC CATHETERIZTN" │ 191          │
# │ 80  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 81  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 82  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 83  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 84  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 85  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
# │ 86  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 5            │
# │ 87  │ 48                 │ "CARDIAC PACEMAKER/DEFIB" │ 161          │
# │ 88  │ 231                │ "OTHER THERAPEUTIC PRCS"  │ 196          │
# │ 89  │ 225                │ "CONV OF CARDIAC RHYTHM"  │ 196          │
# │ 90  │ 216                │ "RESP INTUB/MECH VENTIL"  │ 196          │
#
# │ Row │ APR_DRG_Description                                                    │
# ├─────┼────────────────────────────────────────────────────────────────────────┤
# │ 1   │ "CARDIAC ARREST"                                                       │
# │ 2   │ "CARDIAC ARREST"                                                       │
# │ 3   │ "CARDIAC ARREST"                                                       │
# │ 4   │ "CARDIAC DEFIBRILLATOR & HEART ASSIST IMPLANT"                         │
# │ 5   │ "CARDIAC PACEMAKER & DEFIBRILLATOR REVISION EXCEPT DEVICE REPLACEMENT" │
# │ 6   │ "CARDIAC DEFIBRILLATOR & HEART ASSIST IMPLANT"                         │
# │ 7   │ "CARDIAC ARREST"                                                       │
# │ 8   │ "CARDIAC ARREST"                                                       │
# │ 9   │ "CARDIAC ARREST"                                                       │
# │ 10  │ "CARDIAC ARREST"                                                       │
# │ 11  │ "CARDIAC ARREST"                                                       │
# ⋮
# │ 79  │ "CARDIAC CATHETERIZATION W CIRC DISORD EXC ISCHEMIC HEART DISEASE"     │
# │ 80  │ "CARDIAC ARREST"                                                       │
# │ 81  │ "CARDIAC ARREST"                                                       │
# │ 82  │ "CARDIAC ARREST"                                                       │
# │ 83  │ "CARDIAC ARREST"                                                       │
# │ 84  │ "CARDIAC ARREST"                                                       │
# │ 85  │ "CARDIAC ARREST"                                                       │
# │ 86  │ "TRACHEOSTOMY W MV 96+ HOURS W/O EXTENSIVE PROCEDURE"                  │
# │ 87  │ "CARDIAC DEFIBRILLATOR & HEART ASSIST IMPLANT"                         │
# │ 88  │ "CARDIAC ARREST"                                                       │
# │ 89  │ "CARDIAC ARREST"                                                       │
# │ 90  │ "CARDIAC ARREST"                                                       │
#
# │ Row │ APR_MDC_Code │ APR_MDC_Description                                │
# ├─────┼──────────────┼────────────────────────────────────────────────────┤
# │ 1   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 2   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 3   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 4   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 5   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 6   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 7   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 8   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 9   │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 10  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 11  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# ⋮
# │ 79  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 80  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 81  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 82  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 83  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 84  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 85  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 86  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 87  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 88  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 89  │ 5            │ "Diseases and Disorders of the Circulatory System" │
# │ 90  │ 5            │ "Diseases and Disorders of the Circulatory System" │
#
# │ Row │ APR_Severity_of_Illness_Code │ APR_Severity_of_Illness_Description │
# ├─────┼──────────────────────────────┼─────────────────────────────────────┤
# │ 1   │ 4                            │ "Extreme"                           │
# │ 2   │ 2                            │ "Moderate"                          │
# │ 3   │ 3                            │ "Major"                             │
# │ 4   │ 3                            │ "Major"                             │
# │ 5   │ 2                            │ "Moderate"                          │
# │ 6   │ 2                            │ "Moderate"                          │
# │ 7   │ 4                            │ "Extreme"                           │
# │ 8   │ 4                            │ "Extreme"                           │
# │ 9   │ 3                            │ "Major"                             │
# │ 10  │ 3                            │ "Major"                             │
# │ 11  │ 3                            │ "Major"                             │
# ⋮
# │ 79  │ 4                            │ "Extreme"                           │
# │ 80  │ 4                            │ "Extreme"                           │
# │ 81  │ 3                            │ "Major"                             │
# │ 82  │ 4                            │ "Extreme"                           │
# │ 83  │ 4                            │ "Extreme"                           │
# │ 84  │ 4                            │ "Extreme"                           │
# │ 85  │ 3                            │ "Major"                             │
# │ 86  │ 4                            │ "Extreme"                           │
# │ 87  │ 1                            │ "Minor"                             │
# │ 88  │ 3                            │ "Major"                             │
# │ 89  │ 3                            │ "Major"                             │
# │ 90  │ 3                            │ "Major"                             │
#
# │ Row │ APR_Risk_of_Mortality │ APR_Medical_Surgical_Description │
# ├─────┼───────────────────────┼──────────────────────────────────┤
# │ 1   │ "Extreme"             │ "Medical"                        │
# │ 2   │ "Moderate"            │ "Medical"                        │
# │ 3   │ "Moderate"            │ "Medical"                        │
# │ 4   │ "Extreme"             │ "Surgical"                       │
# │ 5   │ "Extreme"             │ "Surgical"                       │
# │ 6   │ "Major"               │ "Surgical"                       │
# │ 7   │ "Extreme"             │ "Medical"                        │
# │ 8   │ "Extreme"             │ "Medical"                        │
# │ 9   │ "Moderate"            │ "Medical"                        │
# │ 10  │ "Moderate"            │ "Medical"                        │
# │ 11  │ "Major"               │ "Medical"                        │
# ⋮
# │ 79  │ "Extreme"             │ "Medical"                        │
# │ 80  │ "Extreme"             │ "Medical"                        │
# │ 81  │ "Major"               │ "Medical"                        │
# │ 82  │ "Extreme"             │ "Medical"                        │
# │ 83  │ "Extreme"             │ "Medical"                        │
# │ 84  │ "Extreme"             │ "Medical"                        │
# │ 85  │ "Extreme"             │ "Medical"                        │
# │ 86  │ "Extreme"             │ "Surgical"                       │
# │ 87  │ "Moderate"            │ "Surgical"                       │
# │ 88  │ "Major"               │ "Medical"                        │
# │ 89  │ "Major"               │ "Medical"                        │
# │ 90  │ "Major"               │ "Medical"                        │
#
# │ Row │ Payment_Typology_1         │ Payment_Typology_2         │
# ├─────┼────────────────────────────┼────────────────────────────┤
# │ 1   │ "Medicaid"                 │ "Medicaid"                 │
# │ 2   │ "Private Health Insurance" │ ""                         │
# │ 3   │ "Private Health Insurance" │ "Self-Pay"                 │
# │ 4   │ "Medicaid"                 │ ""                         │
# │ 5   │ "Medicare"                 │ "Private Health Insurance" │
# │ 6   │ "Medicare"                 │ "Medicare"                 │
# │ 7   │ "Blue Cross/Blue Shield"   │ ""                         │
# │ 8   │ "Medicare"                 │ "Medicare"                 │
# │ 9   │ "Medicare"                 │ "Medicare"                 │
# │ 10  │ "Private Health Insurance" │ "Self-Pay"                 │
# │ 11  │ "Medicare"                 │ "Medicaid"                 │
# ⋮
# │ 79  │ "Medicare"                 │ "Private Health Insurance" │
# │ 80  │ "Medicare"                 │ "Medicaid"                 │
# │ 81  │ "Medicare"                 │ ""                         │
# │ 82  │ "Medicare"                 │ "Private Health Insurance" │
# │ 83  │ "Medicare"                 │ "Medicare"                 │
# │ 84  │ "Medicare"                 │ "Medicaid"                 │
# │ 85  │ "Medicare"                 │ "Medicaid"                 │
# │ 86  │ "Medicaid"                 │ ""                         │
# │ 87  │ "Medicare"                 │ "Medicaid"                 │
# │ 88  │ "Medicare"                 │ "Medicaid"                 │
# │ 89  │ "Medicare"                 │ "Medicaid"                 │
# │ 90  │ "Medicare"                 │ "Private Health Insurance" │
#
# │ Row │ Payment_Typology_3 │ Attending_Provider_License_Number │
# ├─────┼────────────────────┼───────────────────────────────────┤
# │ 1   │ ""                 │ 175641                            │
# │ 2   │ ""                 │ 40003143                          │
# │ 3   │ ""                 │ 204096                            │
# │ 4   │ ""                 │ 218738                            │
# │ 5   │ "Self-Pay"         │ 199030                            │
# │ 6   │ "Self-Pay"         │ 226781                            │
# │ 7   │ ""                 │ 230825                            │
# │ 8   │ ""                 │ 259185                            │
# │ 9   │ "Medicaid"         │ 113717                            │
# │ 10  │ ""                 │ 210926                            │
# │ 11  │ "Self-Pay"         │ 241675                            │
# ⋮
# │ 79  │ "Self-Pay"         │ 244152                            │
# │ 80  │ ""                 │ 245556                            │
# │ 81  │ ""                 │ 225883                            │
# │ 82  │ "Self-Pay"         │ 199344                            │
# │ 83  │ ""                 │ 156674                            │
# │ 84  │ ""                 │ 255584                            │
# │ 85  │ "Self-Pay"         │ 178351                            │
# │ 86  │ ""                 │ 224331                            │
# │ 87  │ ""                 │ 255124                            │
# │ 88  │ "Self-Pay"         │ 240293                            │
# │ 89  │ ""                 │ 203540                            │
# │ 90  │ "Self-Pay"         │ 125994                            │
#
# │ Row │ Operating_Provider_License_Number │ Other_Provider_License_Number │
# ├─────┼───────────────────────────────────┼───────────────────────────────┤
# │ 1   │ 175641                            │ NA                            │
# │ 2   │ 40003143                          │ NA                            │
# │ 3   │ 204096                            │ NA                            │
# │ 4   │ 178383                            │ NA                            │
# │ 5   │ 199030                            │ NA                            │
# │ 6   │ 110785                            │ NA                            │
# │ 7   │ 230825                            │ NA                            │
# │ 8   │ 259185                            │ NA                            │
# │ 9   │ 113717                            │ 113717                        │
# │ 10  │ 259290                            │ NA                            │
# │ 11  │ 241675                            │ NA                            │
# ⋮
# │ 79  │ 243177                            │ NA                            │
# │ 80  │ 245556                            │ 245556                        │
# │ 81  │ 225883                            │ NA                            │
# │ 82  │ 199344                            │ NA                            │
# │ 83  │ 156674                            │ NA                            │
# │ 84  │ 255584                            │ NA                            │
# │ 85  │ 223552                            │ NA                            │
# │ 86  │ 224331                            │ NA                            │
# │ 87  │ 183151                            │ NA                            │
# │ 88  │ 240293                            │ 240293                        │
# │ 89  │ 203540                            │ 248125                        │
# │ 90  │ 230890                            │ NA                            │
#
# │ Row │ Birth_Weight │ Abortion_Edit_Indicator │
# ├─────┼──────────────┼─────────────────────────┤
# │ 1   │ 0            │ "N"                     │
# │ 2   │ 0            │ "N"                     │
# │ 3   │ 0            │ "N"                     │
# │ 4   │ 0            │ "N"                     │
# │ 5   │ 0            │ "N"                     │
# │ 6   │ 0            │ "N"                     │
# │ 7   │ 0            │ "N"                     │
# │ 8   │ 0            │ "N"                     │
# │ 9   │ 0            │ "N"                     │
# │ 10  │ 0            │ "N"                     │
# │ 11  │ 0            │ "N"                     │
# ⋮
# │ 79  │ 0            │ "N"                     │
# │ 80  │ 0            │ "N"                     │
# │ 81  │ 0            │ "N"                     │
# │ 82  │ 0            │ "N"                     │
# │ 83  │ 0            │ "N"                     │
# │ 84  │ 0            │ "N"                     │
# │ 85  │ 0            │ "N"                     │
# │ 86  │ 0            │ "N"                     │
# │ 87  │ 0            │ "N"                     │
# │ 88  │ 0            │ "N"                     │
# │ 89  │ 0            │ "N"                     │
# │ 90  │ 0            │ "N"                     │
#
# │ Row │ Emergency_Department_Indicator │ Total_Charges │ Total_Costs  │
# ├─────┼────────────────────────────────┼───────────────┼──────────────┤
# │ 1   │ "Y"                            │ "\$36430.08"   │ "\$14131.20"  │
# │ 2   │ "Y"                            │ "\$8287.96"    │ "\$7922.80"   │
# │ 3   │ "Y"                            │ "\$7446.80"    │ "\$1578.40"   │
# │ 4   │ "Y"                            │ "\$94259.94"   │ "\$27700.62"  │
# │ 5   │ "N"                            │ "\$42843.97"   │ "\$16044.22"  │
# │ 6   │ "Y"                            │ "\$90047.00"   │ "\$33064.51"  │
# │ 7   │ "Y"                            │ "\$132366.69"  │ "\$100819.34" │
# │ 8   │ "Y"                            │ "\$96365.30"   │ "\$25411.32"  │
# │ 9   │ "Y"                            │ "\$10403.00"   │ "\$6632.81"   │
# │ 10  │ "Y"                            │ "\$46644.54"   │ "\$8234.67"   │
# │ 11  │ "Y"                            │ "\$23345.39"   │ "\$10009.31"  │
# ⋮
# │ 79  │ "Y"                            │ "\$151414.63"  │ "\$46038.08"  │
# │ 80  │ "N"                            │ "\$10212.79"   │ "\$5042.01"   │
# │ 81  │ "Y"                            │ "\$3609.44"    │ "\$2742.76"   │
# │ 82  │ "Y"                            │ "\$11944.86"   │ "\$3480.51"   │
# │ 83  │ "N"                            │ "\$43754.45"   │ "\$30494.80"  │
# │ 84  │ "Y"                            │ "\$7686.31"    │ "\$3087.81"   │
# │ 85  │ "Y"                            │ "\$36516.64"   │ "\$10896.61"  │
# │ 86  │ "Y"                            │ "\$98382.60"   │ "\$85608.50"  │
# │ 87  │ "Y"                            │ "\$103626.05"  │ "\$40941.87"  │
# │ 88  │ "Y"                            │ "\$6664.00"    │ "\$3661.08"   │
# │ 89  │ "Y"                            │ "\$5422.88"    │ "\$2380.34"   │
# │ 90  │ "Y"                            │ "\$42197.67"   │ "\$16421.16"  │
#
# │ Row │ Survived │ Male │ White │ Black │ Other_Race │ private_insurance │
# ├─────┼──────────┼──────┼───────┼───────┼────────────┼───────────────────┤
# │ 1   │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 2   │ 1        │ 1    │ 0     │ 0     │ 1          │ 1                 │
# │ 3   │ 1        │ 1    │ 1     │ 0     │ 0          │ 1                 │
# │ 4   │ 1        │ 0    │ 0     │ 0     │ 1          │ 0                 │
# │ 5   │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 6   │ 1        │ 1    │ 0     │ 1     │ 0          │ 0                 │
# │ 7   │ 1        │ 0    │ 0     │ 0     │ 1          │ 0                 │
# │ 8   │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 9   │ 0        │ 1    │ 0     │ 1     │ 0          │ 0                 │
# │ 10  │ 1        │ 1    │ 0     │ 1     │ 0          │ 1                 │
# │ 11  │ 0        │ 1    │ 0     │ 0     │ 1          │ 0                 │
# ⋮
# │ 79  │ 1        │ 1    │ 0     │ 0     │ 1          │ 0                 │
# │ 80  │ 0        │ 0    │ 0     │ 1     │ 0          │ 0                 │
# │ 81  │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 82  │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 83  │ 0        │ 1    │ 0     │ 0     │ 1          │ 0                 │
# │ 84  │ 0        │ 0    │ 0     │ 0     │ 1          │ 0                 │
# │ 85  │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 86  │ 0        │ 0    │ 0     │ 1     │ 0          │ 0                 │
# │ 87  │ 1        │ 1    │ 1     │ 0     │ 0          │ 0                 │
# │ 88  │ 0        │ 0    │ 0     │ 1     │ 0          │ 0                 │
# │ 89  │ 0        │ 0    │ 1     │ 0     │ 0          │ 0                 │
# │ 90  │ 0        │ 1    │ 1     │ 0     │ 0          │ 0                 │
#
# │ Row │ medicare │ medicaid │ old50_69 │ old70 │
# ├─────┼──────────┼──────────┼──────────┼───────┤
# │ 1   │ 0        │ 1        │ 1        │ 0     │
# │ 2   │ 0        │ 0        │ 1        │ 0     │
# │ 3   │ 0        │ 0        │ 1        │ 0     │
# │ 4   │ 0        │ 1        │ 1        │ 0     │
# │ 5   │ 1        │ 0        │ 0        │ 1     │
# │ 6   │ 1        │ 0        │ 0        │ 1     │
# │ 7   │ 0        │ 0        │ 0        │ 0     │
# │ 8   │ 1        │ 0        │ 0        │ 1     │
# │ 9   │ 1        │ 0        │ 1        │ 0     │
# │ 10  │ 0        │ 0        │ 1        │ 0     │
# │ 11  │ 1        │ 0        │ 0        │ 1     │
# ⋮
# │ 79  │ 1        │ 0        │ 0        │ 1     │
# │ 80  │ 1        │ 0        │ 0        │ 1     │
# │ 81  │ 1        │ 0        │ 0        │ 1     │
# │ 82  │ 1        │ 0        │ 0        │ 1     │
# │ 83  │ 1        │ 0        │ 0        │ 1     │
# │ 84  │ 1        │ 0        │ 1        │ 0     │
# │ 85  │ 1        │ 0        │ 0        │ 1     │
# │ 86  │ 0        │ 1        │ 0        │ 1     │
# │ 87  │ 1        │ 0        │ 1        │ 0     │
# │ 88  │ 1        │ 0        │ 0        │ 1     │
# │ 89  │ 1        │ 0        │ 0        │ 1     │
# │ 90  │ 1        │ 0        │ 0        │ 1     │

# %% [markdown]
# Fit Models on Training Data

# %%
#MODEL ONE
#conditions on severity of illness and length of stay
function model_one(training_data)
    td_size = size(training_data,1)
    X = [training_data[:APR_Severity_of_Illness_Code].data training_data[:Length_of_Stay] ones(td_size)]
    y = training_data[:Survived].data
    w = X\y
    return (w,X)
end 

#MODEL TWO
#conditions on severity of illness, length of stay, and gender
function model_two(training_data)
    td_size = size(training_data,1)
    X = [training_data[:APR_Severity_of_Illness_Code].data training_data[:Length_of_Stay] training_data[:Male] ones(td_size)]
    y = training_data[:Survived].data
    w = X\y
    return (w,X)
end 

#MODEL THREE
#conditions on severity of illness, length of stay, gender, and age
function model_three(training_data)
    td_size = size(training_data,1)
    #binary value, if age is >= 70
    X = [training_data[:APR_Severity_of_Illness_Code].data training_data[:Length_of_Stay] training_data[:Male] training_data[:old70] ones(td_size)]
    y = training_data[:Survived].data
    w = X\y
    return (w,X)
end
# Out:
# model_three (generic function with 1 method)

# %%
#parameters w for each model
w1 = model_one(train)[1]
w2 = model_two(train)[1]
w3 = model_three(train)[1]
# Out:
# 5-element Array{Float64,1}:
#  -0.25797
#   0.0181296
#   0.149822
#  -0.173995
#   1.08157

# %% [markdown]
# Cross Validation of Models

# %%
@show cross_validate(model_one, train)
@show cross_validate(model_two, train) 
@show cross_validate(model_three, train)
# Out:
# cross_validate(model_one,train) = 0.2479655712050078
# cross_validate(model_two,train) = 0.21193270735524256
# cross_validate(model_three,train) = 0.2061032863849765
# 0.2061032863849765

# %% [markdown]
# Bootstrap Estimate for Models

# %%
w1_bs = bootstrap_estimate(model_one,train)
w2_bs = bootstrap_estimate(model_two,train)
w3_bs = bootstrap_estimate(model_three,train)
# Out:
# 5-element Array{Float64,1}:
#  -0.261573
#   0.0199512
#   0.151448
#  -0.170723
#   1.08012

# %% [markdown]
# Check Model Performance on Validation Set

# %%
@show out_sample_error(w1,model_one,test)
@show out_sample_error(w1_bs,model_one,test)
@show out_sample_error(w2,model_two,test)
@show out_sample_error(w2_bs,model_two,test)
@show out_sample_error(w3,model_three,test)
@show out_sample_error(w3_bs,model_three,test)
# Out:
# out_sample_error(w1,model_one,test) = 0.2
# out_sample_error(w1_bs,model_one,test) = 0.2
# out_sample_error(w2,model_two,test) = 0.18888888888888888
# out_sample_error(w2_bs,model_two,test) = 0.17777777777777778
# out_sample_error(w3,model_three,test) = 0.15555555555555556
# out_sample_error(w3_bs,model_three,test) = 0.15555555555555556
# 0.15555555555555556
